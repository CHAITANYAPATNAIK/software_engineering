# %% [markdown]
# <a href="https://colab.research.google.com/github/CHAITANYAPATNAIK/software_engineering/blob/weather_modeling/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# Coefficients for the quadratic equation: ax^2 + bx + c
a = 0.5
b = 2
c = 1
def weather_model(x):
    return a * x**2 + b * x + c
x_values = np.linspace(-10, 10, 100)
y_values = weather_model(x_values)
plt.plot(x_values, y_values, label='Weather Model')
plt.title('Weather Model')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def weather_model(x, a, b, c):
    return a*x**2 + b*x + c #equation
a = float(input("Enter the value of a: "))#enter the a value
b = float(input("Enter the value of b: "))#enter the b value
c = float(input("Enter the value of c: "))#enter the c value
x_values = np.linspace(-10, 10, 400)#creates a list of 400 values from x axis of -10 to 10
y_values = weather_model(x_values, a, b, c)
x_specific = float(input("Enter the specific value of x: "))# enter the specific x value
y_specific = weather_model(x_specific, a, b, c)
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=f'{a}x^2 + {b}x + {c}')
plt.plot([x_specific], [y_specific], 'ro')  #ro means r-red o-circle
plt.title('Weather Model') #plot the title
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter the value of a: 3.5
# Enter the value of b: 4.5
# Enter the value of c: 5.5
# Enter the specific value of x: 2

# %%
import numpy as np
import matplotlib.pyplot as plt
def weather_model(x, a, b, c):
    return a * np.power(x, 2) + b * x + c
parameters = np.loadtxt('parameters.txt')
x_values = np.linspace(-10, 10, 400)
plt.figure(figsize=(10, 6))
for test in parameters:
    x, a, b, c = test
    y_values = weather_model(x_values, a, b, c)
    plt.plot(x_values, y_values, label=f'{a}x^2 + {b}x + {c}')
plt.title('Quadratic Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Define the quadratic function
def weather_model(x, a, b, c):
    return a * x**2 + b * x + c
# Read parameters from the file
with open('parameters.txt', 'r') as f:
    lines = f.readlines()
# Generate x values using NumPy linspace
x_values = np.linspace(-10, 10, 400)
# Create a figure for the plot
plt.figure(figsize=(10, 6))
# Loop through each line in the file to extract parameters
for line in lines:
    x_specific, a, b, c = map(float, line.split())

    # Calculate y values for the entire range of x values
    y_values = weather_model(x_values, a, b, c)
    # Calculate y value for the specific x value
    y_specific = weather_model(x_specific, a, b, c)
    # Plot the quadratic function for the entire range
    plt.plot(x_values, y_values, label=f'{a}x^2 + {b}x + {c}')
    # Plot the specific point in red
    plt.plot(x_specific, y_specific, 'ro')
# Adding labels and title to the plot
plt.title('Quadratic Functions')
plt.xlabel('x')
plt.ylabel('y')
# Displaying the legend
plt.legend()
# Displaying the grid on the plot
plt.grid(True)
# Showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temperature_model(time, a, b, c):
    """
    Quadratic temperature model: T(time) = a*time^2 + b*time + c
    """
    return a * time**2 + b * time + c

def plot_temperature_model(a, b, c):
    """
    Plot the quadratic temperature model for a specific day.
    """
    time_values = np.linspace(0, 24, 100)  # 24 hours in a day
    temperature_values = quadratic_temperature_model(time_values, a, b, c)

    plt.figure(figsize=(10, 6))
    plt.plot(time_values, temperature_values, label='Temperature Model', color='blue')
    plt.xlabel('Time (hours)')
    plt.ylabel('Temperature')
    plt.title('Quadratic Temperature Model for a Day')
    plt.legend()
    plt.grid(True)
    plt.show()

def main():
    # Hard-coded coefficients for the quadratic equation
    a_fixed = 0.02
    b_fixed = 1.5
    c_fixed = 20

    # Get user input for coefficients (you can customize this part)
    a_user = float(input("Enter a coefficient for time: "))
    b_user = float(input("Enter a coefficient for time: "))
    c_user = float(input("Enter a constant term: "))

    # Combine fixed and user coefficients
    a_combined = a_fixed + a_user
    b_combined = b_fixed + b_user
    c_combined = c_fixed + c_user

    # Plot the temperature model
    plot_temperature_model(a_combined, b_combined, c_combined)

if __name__ == "__main__":
    main()
# Out:
# Enter a coefficient for time: 4
# Enter a coefficient for time: 6
# Enter a constant term: 3
